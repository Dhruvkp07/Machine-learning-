# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get("https://internshala.com/internships/internship-in-delhi",headers=headers).text

# %%
Soup=BeautifulSoup(webpage,'lxml')

# %%
for i in Soup.find_all("a",class_="job-title-href"):
  print(i.text.strip())
# Out:
# Travel Consultant
# Business Development (Sales)
# Pitch Curator
# International Business Development
# Embedded Systems
# Human Resources (HR)
# Telecalling
# Marketing
# Content and Social Media Marketing
# Lead Generation
# Events And Marketing
# Recruitment
# Graphic Design
# Event Hosting & Facilitator
# Field Sales
# Process Coordinator/ HR Executive
# Social Media Marketing
# Field Sales
# Human Resources (HR)
# Graphic Design
# Social Media Marketing
# Vendor Research (Procurement / Supply Chain)
# Customer Service/Customer Support
# Data Entry
# Content Writing
# Content & Website Management
# Operations
# Marketing
# Omni Sports Adviser
# Proposal Writing Support
# Business Research
# Business Strategy
# Telecalling
# Sales and Marketing
# Customer Service/Customer Support
# Admission Coordinator (Japanese Language Academy)
# Sales
# Anchoring
# Content Writing
# Business Development (Sales)
# Video & Content Creation
# Customer Relationship Manangement
# ...

# %% [markdown]
# website = https://internshala.com/internships/internship-in-delhi

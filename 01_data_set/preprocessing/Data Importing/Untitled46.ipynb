# %% [markdown]
# ## How to Read csv files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/pokemon[1].csv")
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %% [markdown]
# ## For Tsv ( tab seprated files )

# %% [markdown]
# At end (... ,sep="\t")

# %% [markdown]
# Where "sep" is used for sepration and "\t" used for tab

# %%
tf = pd.read_csv("/content/drive/MyDrive/demo_mlexpec[1].tsv",sep="\t")
tf.head()
# Out:
#   unit,sex,age,geo\time 2021   2020   2019   2018   2017   2016   2015   \
# 0            YR,F,Y1,AL    :   79.4   80.4   80.2   79.7   79.8   79.2
# 1            YR,F,Y1,AM    :      :   79.1   79.2   78.5   78.0   77.9
# 2            YR,F,Y1,AT    :   82.9   83.5   83.3   83.2   83.4   83.0
# 3            YR,F,Y1,AZ    :      :   78.6   78.1   77.7      :   77.5
# 4            YR,F,Y1,BE    :   82.3   83.6   83.2   83.2   83.2   82.6
#
#    2014   2013   ...  1969   1968   1967   1966   1965   1964   1963   1962   \
# 0  79.8   79.6   ...     :      :      :      :      :      :      :      :
# 1     :      :   ...     :      :      :      :      :      :      :      :
# 2  83.3   83.0   ...     :      :      :      :      :      :      :      :
# 3  77.0   76.9   ...     :      :      :      :      :      :      :      :
# 4  83.1   82.5   ...  74.4   74.3   74.7   74.4   74.3   74.6   73.9   74.0
#
#    1961   1960
# 0     :      :
# 1     :      :
# 2     :      :
# ...

# %% [markdown]
# ## For JSON dataset

# %%
json = pd.read_json("/content/drive/MyDrive/iris[1].json")
json.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa
